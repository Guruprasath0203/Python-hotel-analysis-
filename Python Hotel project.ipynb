# %% [markdown]
# # AtliQ Hotels Data Analysis Project

# %% [markdown]
# Data Import and Data Exploration

# %% [markdown]
# Importing CSV file "fact_bookings.csv"

# %%
#first step is to import the dataset using pandas ("always check for spellings")

import pandas as pd

df_bookings = pd.read_csv("fact_bookings.csv")
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
# step 2 to check the shape of the dataset
df_bookings.shape
# Out:
# (134590, 12)

# %%
# to check the unique platform we use unique command
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
#in the above step we got the platforms of booking patform 
#now we need to know the number of bookings from each platform
df_bookings.booking_platform.value_counts()
# Out:
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: booking_platform, dtype: int64

# %%
#here it gets intresting we can use visuals using charts 
#Sometime visuals tells more story than numbers ("keep it in mind")

df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#another trick we can also use horizantal bar charts to define the data

df_bookings.booking_platform.value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %%
#To get the stats of the dataset we use describe function

df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
# okay lets get the min and max of revenue of the booking dataset

df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %% [raw]
# Importing required csv files :
#     dim_date.csv
#     dim_hotels.csv
#     dim_rooms.csv
#     fact_aggregated_bookings.csv

# %%
df_date = pd.read_csv("dim_date.csv")
df_hotels = pd.read_csv("dim_hotels.csv")
df_rooms = pd.read_csv("dim_rooms.csv")
df_facts_agg_booking = pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_rooms.shape
# Out:
# (4, 2)

# %%
df_hotels.shape
# Out:
# (25, 4)

# %% [raw]
# Using head(3) ::: 3 is used to display top 3 records also can use tail(3) to get bottom 3 record of the table

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %% [raw]
# Using values_counts() to identify the total numbers

# %%
df_hotels.category.value_counts()
# Out:
# Luxury      16
# Business     9
# Name: category, dtype: int64

# %% [raw]
# Here we use pandas to visual the record sometime chats are more easier to understand:
#     plot(kind="bar") or plot(kind="barh") or plot(kind="pie")

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df_facts_agg_booking.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %% [raw]
# .unique() is used to find the unique data from the database

# %%
df_facts_agg_booking.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %% [raw]
# Here is the most tricky part we use 5 csv file to analysis the data so here we are using groupby to get the values

# %%
df_facts_agg_booking.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_facts_agg_booking[df_facts_agg_booking.successful_bookings>df_facts_agg_booking.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [raw]
# We can use min() and max() to get the minimum and maximum values of  paticular column

# %%
df_facts_agg_booking.capacity.max()
# Out:
# 50.0

# %% [raw]
# "==" is used to find the equal values in the table

# %%
df_facts_agg_booking[df_facts_agg_booking.capacity==df_facts_agg_booking.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# Data Cleaning

# %% [raw]
# Here describe is used to get the detailed analysis of the dataset

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings= df_bookings[df_bookings.no_guests>0]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
avg,std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg,std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263742.4278566132

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134578.000000
# mean      12696.011822
# std        6927.841641
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33479.53674501789

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings.isnull()
# Out:
#         booking_id  property_id  booking_date  check_in_date  checkout_date  \
# 1            False        False         False          False          False
# 2            False        False         False          False          False
# 4            False        False         False          False          False
# 5            False        False         False          False          False
# 6            False        False         False          False          False
# ...            ...          ...           ...            ...            ...
# 134584       False        False         False          False          False
# 134585       False        False         False          False          False
# 134587       False        False         False          False          False
# 134588       False        False         False          False          False
# 134589       False        False         False          False          False
#
# ...

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77899
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_facts_agg_booking
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_facts_agg_booking.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_facts_agg_booking[df_facts_agg_booking.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_facts_agg_booking.capacity.median()
# Out:
# 25.0

# %%
df_facts_agg_booking.capacity.fillna(df_facts_agg_booking.capacity.median(),inplace=True)

# %%
df_facts_agg_booking.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %%
df_facts_agg_booking[df_facts_agg_booking.successful_bookings>df_facts_agg_booking.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_facts_agg_booking.shape
# Out:
# (9200, 5)

# %%
df_facts_agg_booking = df_facts_agg_booking[df_facts_agg_booking.successful_bookings<=df_facts_agg_booking.capacity]
df_facts_agg_booking.shape
# Out:
# (9194, 5)

# %% [markdown]
# Data Transforming

# %%
df_facts_agg_booking ["occ_pct"] = df_facts_agg_booking["successful_bookings"]/df_facts_agg_booking["capacity"]
df_facts_agg_booking.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
df_facts_agg_booking ["occ_pct"] =df_facts_agg_booking ["occ_pct"].apply(lambda x: round(x*100,2))
df_facts_agg_booking.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 4    94.74
# 5    70.00

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %%
df_facts_agg_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occ_pct              9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %% [markdown]
# Ad hoc analysis

# %% [markdown]
# Insight generation

# %%
df_facts_agg_booking.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_facts_agg_booking,df_rooms, left_on="room_category",right_on = "room_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id",axis=1,inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3    94.74   Standard

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df = pd.merge(df,df_hotels,on="property_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
#
#    occ_pct room_class  property_name category    city
# 0    83.33   Standard  Atliq Exotica   Luxury  Mumbai
# 1    66.67   Standard  Atliq Exotica   Luxury  Mumbai
# 2    56.67   Standard  Atliq Exotica   Luxury  Mumbai
# 3    70.00   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ_pct"].mean().plot(kind="barh")
# Out:
# <Axes: ylabel='city'>

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df = pd.merge(df,df_date, left_on = "check_in_date",right_on="date")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
#
#    occ_pct    room_class  property_name category    city       date  mmm yy  \
# 0    60.00      Standard  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 1    60.98         Elite  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 2    62.50       Premium  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 3    72.22  Presidential  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday
# 3    W 20  weekeday

# %%
df.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occ_pct, dtype: float64

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_Jun_22 = df[df["mmm yy"]=="Jun 22"]
df_Jun_22.head(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
#
#       occ_pct    room_class  property_name category    city       date  \
# 2200    66.67      Standard  Atliq Exotica   Luxury  Mumbai  10-Jun-22
# 2201    63.41         Elite  Atliq Exotica   Luxury  Mumbai  10-Jun-22
# 2202    62.50       Premium  Atliq Exotica   Luxury  Mumbai  10-Jun-22
# 2203    61.11  Presidential  Atliq Exotica   Luxury  Mumbai  10-Jun-22
#
#       mmm yy week no  day_type
# 2200  Jun 22    W 24  weekeday
# 2201  Jun 22    W 24  weekeday
# 2202  Jun 22    W 24  weekeday
# 2203  Jun 22    W 24  weekeday

# %%
df_Jun_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: occ_pct, dtype: float64

# %%
df_august = pd.read_csv("new_data_august.csv")
df_august
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
latest_df = pd.concat([df,df_august],ignore_index=True,axis=0)
latest_df.tail(5)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct room_class  property_name  category       city date  mmm yy  \
# 6499      NaN   Standard   Atliq Palace  Business  Bangalore  NaN  Aug-22
# 6500      NaN   Standard   Atliq Grands    Luxury  Bangalore  NaN  Aug-22
# 6501      NaN   Standard     Atliq City  Business  Bangalore  NaN  Aug-22
# 6502      NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN  Aug-22
# 6503      NaN   Standard  Atliq Seasons  Business     Mumbai  NaN  Aug-22
#
#      week no  day_type   occ%
# ...

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_bookings_all = pd.merge(df_bookings,df_hotels, on= "property_id")
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 2  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1            9100000              9100  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all.groupby("city")["revenue_generated"].sum()
# Out:
# city
# Bangalore    494814675
# Delhi        378050550
# Hyderabad    381333250
# Mumbai       815346980
# Name: revenue_generated, dtype: int64

# %%
 pd.merge(df_bookings_all,df_date, left_on= "check_in_date",right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  object
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] = pd.to_datetime(df_date["date"])
df_date.head(4)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(df_bookings_all["check_in_date"])
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 1  May012216558RT13        16558     28-04-22    2022-01-05      4/5/2022
# 2  May012216558RT15        16558     27-04-22    2022-01-05      2/5/2022
# 3  May012216558RT16        16558     1/5/2022    2022-01-05      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1            9100000              9100  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  datetime64[ns]
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
 df_bookings_all = pd.merge(df_bookings_all,df_date, left_on= "check_in_date",right_on="date")
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    389953512
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.property_name.unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_bookings_all.groupby("property_name")["revenue_realized"].sum().round(2).sort_values()
# Out:
# property_name
# Atliq Seasons     45920757
# Atliq Grands     145860641
# Atliq Blu        179203544
# Atliq Bay        179429321
# Atliq City       196555383
# Atliq Palace     209474575
# Atliq Exotica    219076161
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.groupby("city")["ratings_given"].mean().round(2)
# Out:
# city
# Bangalore    3.40
# Delhi        3.77
# Hyderabad    3.66
# Mumbai       3.64
# Name: ratings_given, dtype: float64

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='revenue_realized'>
